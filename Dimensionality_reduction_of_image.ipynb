# %% [markdown]
# Missing Value Ratio,
# Low Variance Filter,
# High Correlation Filter,
# Random Forest,
# Backward Feature Elimination,
# Forward Feature Selection,
# Factor Analysis,
# Principal Component Analysis,
# Independent Component Analysis,
# Methods Based on Projections,
# t-Distributed Stochastic Neighbor Embedding (t-SNE),
# UMAP,
# Linear Discriminant Analysis,
# Isomap Embedding,
# Locally Linear Embedding,
# Modified Locally Linear Embedding,
# Kernel PCA,
# Incremental PCA,
# Sparse PCA,
# MultiDimensional Scaling,
# MiniBatch Dictionary Learning,
# Autoencoders

# %% [markdown]
# yes

# %%
from sklearn import datasets
d=datasets.load_digits()
x=d.data
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
xc=s.fit_transform(x)
from sklearn.decomposition import PCA
p=PCA().fit(xc)
nd=p.transform(xc)
import matplotlib.pyplot as pl
import numpy as n
pl.plot(n.cumsum(p.explained_variance_ratio_))
pl.xlabel('no of components')
pl.ylabel('total explained variance')
pl.show()

# %% [markdown]
# less than 30 dimensions capture 90% of variance
